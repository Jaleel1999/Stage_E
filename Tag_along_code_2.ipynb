# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
df = pd.read_csv("Time_series_analysis.csv")

# %%
df
# Out:
#                   FullDate  Tmax     SysLoad  GasPrice  ElecPrice
# 0      2010-09-01 00:00:00  15.8  1688.21500    3.6900     23.710
# 1      2010-09-01 01:00:00  15.8  1669.19500    3.6900     22.635
# 2      2010-09-01 02:00:00  15.8  1491.98000    3.6900     22.565
# 3      2010-09-01 03:00:00  15.8  1330.76000    3.6900     18.910
# 4      2010-09-01 04:00:00  15.8  1247.94000    3.6900     18.030
# ...                    ...   ...         ...       ...        ...
# 92011  2021-02-28 19:00:00  24.3   449.63625    5.4848    117.925
# 92012  2021-02-28 20:00:00  24.3   815.59975    5.4848     87.880
# 92013  2021-02-28 21:00:00  24.3   745.12325    5.4848     62.060
# 92014  2021-02-28 22:00:00  24.3   694.95150    5.4848     62.000
# 92015  2021-02-28 23:00:00  24.3   714.69630    5.4848     62.955
#
# [92016 rows x 5 columns]

# %%
df[["SysLoad","Tmax","GasPrice","ElecPrice"]]
# Out:
#           SysLoad  Tmax  GasPrice  ElecPrice
# 0      1688.21500  15.8    3.6900     23.710
# 1      1669.19500  15.8    3.6900     22.635
# 2      1491.98000  15.8    3.6900     22.565
# 3      1330.76000  15.8    3.6900     18.910
# 4      1247.94000  15.8    3.6900     18.030
# ...           ...   ...       ...        ...
# 92011   449.63625  24.3    5.4848    117.925
# 92012   815.59975  24.3    5.4848     87.880
# 92013   745.12325  24.3    5.4848     62.060
# 92014   694.95150  24.3    5.4848     62.000
# 92015   714.69630  24.3    5.4848     62.955
#
# [92016 rows x 4 columns]

# %%
model = Prophet()

# %%
model.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27624\486985857.py in <module>
# ----> 1 model.fit(df)
#
# ~\anaconda3\lib\site-packages\prophet\forecaster.py in fit(self, df, **kwargs)
#    1115                             'Instantiate a new object.')
#    1116         if ('ds' not in df) or ('y' not in df):
# -> 1117             raise ValueError(
#    1118                 'Dataframe must have columns "ds" and "y" with the dates and '
#    1119                 'values respectively.'
#
# ValueError: Dataframe must have columns "ds" and "y" with the dates and values respectively.
